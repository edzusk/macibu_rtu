# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/kopa_cesu_pils_valstis_pa_gadiem_menesiem.csv', sep = ';')

# %%
filter = (df.gads == 2019) & (df.KOPĀ >= 100)

df[filter]
# Out:
#                         Valsts  janvāris  februāris   marts  aprīlis   maijs  \
# 462                 LV Vidzeme     107.0      275.0   165.0    685.0  1002.0
# 463                 LV Latgale      19.0        7.0     8.0     57.0   361.0
# 464                 LV Zemgale      15.0        7.0    15.0     16.0   227.0
# 465                 LV Kurzeme      15.0        9.0    25.0     88.0   198.0
# 466                   LV Cēsis     106.0      317.0   124.0    125.0   426.0
# 467                    LV Rīga     219.0      421.0   552.0    437.0  1247.0
# 468               Kopā Latvija     481.0     1036.0   889.0   1408.0  3461.0
# 469                   Igaunija      76.0       98.0    97.0    181.0   373.0
# 470                    Lietuva      49.0       31.0    21.0    117.0   288.0
# 471                   Krievija    1024.0      237.0   298.0    244.0   922.0
# 472                    Ukraina       5.0        9.0    11.0      8.0    40.0
# ...

# %%
df[filter].plot.bar(y='KOPĀ', x='Valsts' )
# Out:
# <AxesSubplot:xlabel='Valsts'>
